# %%
# !python -m pip install apricot-select
# Out:
# /System/Library/Frameworks/Python.framework/Versions/2.7/Resources/Python.app/Contents/MacOS/Python: No module named pip

# %%
import os
print(os.getcwd())
import sys
sys.path.append("..")
# Out:
# /Users/ping/Google Drive/cords/notebooks

# %%
# %pwd
# %cd /Users/ping/Google Drive/cords/
# Out:
# /Users/ping/Google Drive/cords

# %%
from train import TrainClassifier

# %%
# GLISTER
config_file = "configs/config_tabular.py"

# airline
classifier_airline = TrainClassifier(config_file)
classifier_airline.configdata["dataset"]["name"] = "airline"
classifier_airline.configdata["dss_strategy"]["type"] = "GLISTER"
classifier_airline.configdata["dss_strategy"]["fraction"] = 0.1
classifier_airline.configdata["dss_strategy"]["select_every"] = 20
classifier_airline.configdata["model"]["input_dim"] = 499
classifier_airline.configdata["model"]["numclasses"] = 2
classifier_airline.train()

# loan
classifier_loan = TrainClassifier(config_file)
classifier_loan.configdata["dataset"]["name"] = "loan"
classifier_loan.configdata["dss_strategy"]["type"] = "GLISTER"
classifier_loan.configdata["dss_strategy"]["fraction"] = 0.1
classifier_loan.configdata["dss_strategy"]["select_every"] = 20
classifier_loan.configdata["model"]["input_dim"] = 409
classifier_loan.configdata["model"]["numclasses"] = 2
classifier_loan.train()

# olympic
classifier_olympic = TrainClassifier(config_file)
classifier_olympic.configdata["dataset"]["name"] = "olympic"
classifier_olympic.configdata["dss_strategy"]["type"] = "GLISTER"
classifier_olympic.configdata["dss_strategy"]["fraction"] = 0.1
classifier_olympic.configdata["dss_strategy"]["select_every"] = 20
classifier_olympic.configdata["model"]["input_dim"] = 2735
classifier_olympic.configdata["model"]["numclasses"] = 4
classifier_olympic.train()
# Out:
# Budget, fraction and N: 9091 0.1 90916
# Epoch: 1 , Validation Loss: 4.325669556856155 , Validation Accuracy: 0.8664048664048664 , Test Loss: 8.67684492468834 , Test Accuracy: 0.8658043654001617 , Timing: 0.35144495964050293
# Epoch: 2 , Validation Loss: 3.8996582329273224 , Validation Accuracy: 0.8829598829598829 , Test Loss: 7.820732533931732 , Test Accuracy: 0.8796627786118489 , Timing: 0.3379058837890625
# Epoch: 3 , Validation Loss: 3.449162483215332 , Validation Accuracy: 0.8963578963578963 , Test Loss: 6.930360972881317 , Test Accuracy: 0.8932132270854987 , Timing: 0.3164029121398926
# Epoch: 4 , Validation Loss: 3.1012412905693054 , Validation Accuracy: 0.9057519057519058 , Test Loss: 6.2195690125226974 , Test Accuracy: 0.9024136736343689 , Timing: 0.4286201000213623
# Epoch: 5 , Validation Loss: 2.902989372611046 , Validation Accuracy: 0.9096789096789096 , Test Loss: 5.8092445731163025 , Test Accuracy: 0.9078415521422797 , Timing: 0.4468231201171875
# ...

# %%
# Glister-warm
config_file = "configs/config_tabular.py"

# airline
classifier_airline = TrainClassifier(config_file)
classifier_airline.configdata["dataset"]["name"] = "airline"
classifier_airline.configdata["dss_strategy"]["type"] = "GLISTER-Warm"
classifier_airline.configdata["dss_strategy"]["fraction"] = 0.1
classifier_airline.configdata["dss_strategy"]["select_every"] = 20
classifier_airline.configdata["dss_strategy"]["kappa"] = 0.6
classifier_airline.configdata["model"]["input_dim"] = 499
classifier_airline.configdata["model"]["numclasses"] = 2
classifier_airline.train()

# loan
classifier_loan = TrainClassifier(config_file)
classifier_loan.configdata["dataset"]["name"] = "loan"
classifier_loan.configdata["dss_strategy"]["type"] = "GLISTER-Warm"
classifier_loan.configdata["dss_strategy"]["fraction"] = 0.1
classifier_loan.configdata["dss_strategy"]["select_every"] = 20
classifier_loan.configdata["dss_strategy"]["kappa"] = 0.6
classifier_loan.configdata["model"]["input_dim"] = 409
classifier_loan.configdata["model"]["numclasses"] = 2
classifier_loan.train()

# olympic
classifier_olympic = TrainClassifier(config_file)
classifier_olympic.configdata["dataset"]["name"] = "olympic"
classifier_olympic.configdata["dss_strategy"]["type"] = "GLISTER-Warm"
classifier_olympic.configdata["dss_strategy"]["fraction"] = 0.1
classifier_olympic.configdata["dss_strategy"]["select_every"] = 20
classifier_olympic.configdata["dss_strategy"]["kappa"] = 0.6
classifier_olympic.configdata["model"]["input_dim"] = 2735
classifier_olympic.configdata["model"]["numclasses"] = 4
classifier_olympic.train()
# Out:
# Budget, fraction and N: 9091 0.1 90916
# Epoch: 1 , Validation Loss: 2.4311808943748474 , Validation Accuracy: 0.9214599214599215 , Test Loss: 4.887198761105537 , Test Accuracy: 0.9200831504792701 , Timing: 2.7635769844055176
# Epoch: 2 , Validation Loss: 2.1050466001033783 , Validation Accuracy: 0.9330869330869331 , Test Loss: 4.211413085460663 , Test Accuracy: 0.9315548369711668 , Timing: 2.7754111289978027
# Epoch: 3 , Validation Loss: 1.974084883928299 , Validation Accuracy: 0.9377069377069377 , Test Loss: 3.9465755820274353 , Test Accuracy: 0.9356353697501636 , Timing: 2.768523931503296
# Epoch: 4 , Validation Loss: 1.9174864590168 , Validation Accuracy: 0.9402479402479402 , Test Loss: 3.8175563663244247 , Test Accuracy: 0.9369827154790776 , Timing: 2.817610025405884
# Epoch: 5 , Validation Loss: 1.8834993094205856 , Validation Accuracy: 0.9411719411719411 , Test Loss: 3.7487327307462692 , Test Accuracy: 0.9388305039073026 , Timing: 2.703768730163574
# ...

# %%
# Random-Online
config_file = "configs/config_tabular.py"

# airline
classifier_airline = TrainClassifier(config_file)
classifier_airline.configdata["dataset"]["name"] = "airline"
classifier_airline.configdata["dss_strategy"]["type"] = "Random-Online"
classifier_airline.configdata["dss_strategy"]["fraction"] = 0.1
classifier_airline.configdata["dss_strategy"]["select_every"] = 20
classifier_airline.configdata["dss_strategy"]["kappa"] = 0.6
classifier_airline.configdata["model"]["input_dim"] = 499
classifier_airline.configdata["model"]["numclasses"] = 2
classifier_airline.train()

# loan
classifier_loan = TrainClassifier(config_file)
classifier_loan.configdata["dataset"]["name"] = "loan"
classifier_loan.configdata["dss_strategy"]["type"] = "Random-Online"
classifier_loan.configdata["dss_strategy"]["fraction"] = 0.1
classifier_loan.configdata["dss_strategy"]["select_every"] = 20
classifier_loan.configdata["dss_strategy"]["kappa"] = 0.6
classifier_loan.configdata["model"]["input_dim"] = 409
classifier_loan.configdata["model"]["numclasses"] = 2
classifier_loan.train()

# olympic
classifier_olympic = TrainClassifier(config_file)
classifier_olympic.configdata["dataset"]["name"] = "olympic"
classifier_olympic.configdata["dss_strategy"]["type"] = "Random-Online"
classifier_olympic.configdata["dss_strategy"]["fraction"] = 0.1
classifier_olympic.configdata["dss_strategy"]["select_every"] = 20
classifier_olympic.configdata["dss_strategy"]["kappa"] = 0.6
classifier_olympic.configdata["model"]["input_dim"] = 2735
classifier_olympic.configdata["model"]["numclasses"] = 4
classifier_olympic.train()
# Out:
# Budget, fraction and N: 9091 0.1 90916
# Epoch: 1 , Validation Loss: 4.2937182784080505 , Validation Accuracy: 0.8738738738738738 , Test Loss: 8.616096049547195 , Test Accuracy: 0.8739269353659006 , Timing: 0.3060131072998047
# Epoch: 2 , Validation Loss: 4.133549690246582 , Validation Accuracy: 0.8690998690998691 , Test Loss: 8.349706649780273 , Test Accuracy: 0.8685760480424991 , Timing: 0.2833828926086426
# Epoch: 3 , Validation Loss: 3.622561603784561 , Validation Accuracy: 0.891044891044891 , Test Loss: 7.347472742199898 , Test Accuracy: 0.8862455248874004 , Timing: 0.29172325134277344
# Epoch: 4 , Validation Loss: 3.578556567430496 , Validation Accuracy: 0.8844998844998845 , Test Loss: 7.209883973002434 , Test Accuracy: 0.884936674750741 , Timing: 0.2837560176849365
# Epoch: 5 , Validation Loss: 2.937870964407921 , Validation Accuracy: 0.9085239085239085 , Test Loss: 5.924894526600838 , Test Accuracy: 0.9058012857527813 , Timing: 0.27242231369018555
# ...

# %%
# Full
config_file = "configs/config_tabular.py"

# airline
classifier_airline = TrainClassifier(config_file)
classifier_airline.configdata["dataset"]["name"] = "airline"
classifier_airline.configdata["dss_strategy"]["type"] = "Full"
classifier_airline.configdata["dss_strategy"]["fraction"] = 0.1
classifier_airline.configdata["dss_strategy"]["select_every"] = 20
classifier_airline.configdata["model"]["input_dim"] = 499
classifier_airline.configdata["model"]["numclasses"] = 2
classifier_airline.train()

# loan
classifier_loan = TrainClassifier(config_file)
classifier_loan.configdata["dataset"]["name"] = "loan"
classifier_loan.configdata["dss_strategy"]["type"] = "Full"
classifier_loan.configdata["dss_strategy"]["fraction"] = 0.1
classifier_loan.configdata["dss_strategy"]["select_every"] = 20
classifier_loan.configdata["model"]["input_dim"] = 409
classifier_loan.configdata["model"]["numclasses"] = 2
classifier_loan.train()

# olympic
classifier_olympic = TrainClassifier(config_file)
classifier_olympic.configdata["dataset"]["name"] = "olympic"
classifier_olympic.configdata["dss_strategy"]["type"] = "Full"
classifier_olympic.configdata["dss_strategy"]["fraction"] = 0.1
classifier_olympic.configdata["dss_strategy"]["select_every"] = 20
classifier_olympic.configdata["model"]["input_dim"] = 2735
classifier_olympic.configdata["model"]["numclasses"] = 4
classifier_olympic.train()
# Out:
# Budget, fraction and N: 9091 0.1 90916
# Epoch: 1 , Validation Loss: 2.381204068660736 , Validation Accuracy: 0.923923923923924 , Test Loss: 4.784841895103455 , Test Accuracy: 0.9220464256842592 , Timing: 2.748396158218384
# Epoch: 2 , Validation Loss: 2.0660179555416107 , Validation Accuracy: 0.936012936012936 , Test Loss: 4.1335190534591675 , Test Accuracy: 0.9332101474381184 , Timing: 2.7404680252075195
# Epoch: 3 , Validation Loss: 1.9969765841960907 , Validation Accuracy: 0.9357819357819358 , Test Loss: 3.9808298647403717 , Test Accuracy: 0.9332101474381184 , Timing: 2.787508964538574
# Epoch: 4 , Validation Loss: 1.9143372178077698 , Validation Accuracy: 0.9394779394779394 , Test Loss: 3.801845222711563 , Test Accuracy: 0.936443777187512 , Timing: 2.7626049518585205
# Epoch: 5 , Validation Loss: 1.8653634339571 , Validation Accuracy: 0.942018942018942 , Test Loss: 3.705335333943367 , Test Accuracy: 0.9392154598298494 , Timing: 2.736492156982422
# ...
